# %%
import sys
sys.path.append("CameraScript")
from CameraScript import takePic
import os
os.environ["LIBCAMERA_LOG_LEVELS"] = "2"
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

print("Done")
# Out:
# Done

# %%
test, StartFocusVal, FinalFocusVal = takePic()
plt.imshow(test)
plt.show()
print(StartFocusVal, FinalFocusVal)
# Out:
# 0.0 0.0
