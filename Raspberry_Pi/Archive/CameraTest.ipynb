# %%
# !libcamera-hello --tuning-file /usr/share/libcamera/ipa/rpi/vc4/imx219_noir.json -n
from picamera2 import Picamera2
from time import sleep
from PIL import Image
import os
os.environ["LIBCAMERA_LOG_LEVELS"] = "3"
import matplotlib.pyplot as plt
# %matplotlib inline

print("Done")
# Out:
# Done

# %%
capture_file = 1
camera = Picamera2()

capture_config = camera.create_still_configuration()

camera.start()
sleep(2)
filename = "test_full.jpg"
if capture_file:
    picam2.switch_mode_and_capture_file(capture_config, filename)
    image = Image.open(filename)
elif not capture_file:
    image = camera.switch_mode_and_capture_array(capture_config, "main")
camera.stop()

plt.imshow(image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
